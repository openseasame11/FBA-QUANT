# %% [markdown]
# ### 1-4

# %% [markdown]
# * 3번의 경우, 솔루션을 참고하여 작성하였지만 과정을 완전히 이해하지는 못했습니다

# %% [markdown]
# ![P1~P4.png](data:image/png;base64,...)

# %% [markdown]
# ## 5

# %%
def stairs(n):
  if n <= 0:
    return 0
  elif n == 1:
    return 1
  elif n == 2:
    return 2
  elif n == 3:
    return 4
  else:
    return stairs(n-3) + stairs(n-2) + stairs(n-1)
