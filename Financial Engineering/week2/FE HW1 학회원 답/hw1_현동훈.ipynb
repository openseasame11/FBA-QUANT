# %% [markdown]
# # Assignment

# %% [markdown]
# 1.

# %% [markdown]
# ![CamScanner%2002-11-2023%2018.47_1.jpg](attachment:CamScanner%2002-11-2023%2018.47_1.jpg)

# %% [markdown]
# 2.

# %% [markdown]
# ![CamScanner%2002-11-2023%2018.47_2.jpg](attachment:CamScanner%2002-11-2023%2018.47_2.jpg)

# %% [markdown]
# 3.

# %% [markdown]
# ![CamScanner%2002-11-2023%2018.47_4.jpg](attachment:CamScanner%2002-11-2023%2018.47_4.jpg)

# %% [markdown]
# 4.

# %% [markdown]
# ![CamScanner%2002-11-2023%2018.47_3.jpg](attachment:CamScanner%2002-11-2023%2018.47_3.jpg)
