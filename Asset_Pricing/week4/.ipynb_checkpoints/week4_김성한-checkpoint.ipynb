# %% [markdown]
# # AP_HW3_김성한

# %% [markdown]
# ## Assignment 1.
# Summarize this week's study.

# %% [markdown]
# # Investment Science
# ## Chapter 6. Mean-variance Portfolio Theory
#
# ### 6.1. Asset Return
# a. The total return(R) is $ \frac{amount \, received}{amount \, invested} = \frac{X_1}{X_0}$. <br/>
# b. The rate of return(r) is $\frac{amount \, received - amount \, invested}{amount\,invested}= \frac{X_1 - X_0}{X_0}$. <br/>
# c. $R = 1+r$ and $X_1 = (1+r)X_0$<br/>
# d. The process of Short selling, or shorting
# - Borrowing the asset from someone who owns it (such as a brokeage firm).
# - Sell the borrowed asset to someone else, receiving an amount $X_0$.
# - At a later date, repay your loan by purchasing the asset $X_1$ and return the asset to your lender.
# - If the later amount $x_1$ is lower than the original amount, you will have made a profit of $X_0 - X_1$.
#
# $$ R = \frac{-X_1}{-X_0} = \frac{X_1}{X_0}$$
#
# e. Portfolio return: Both the total return and the rate of return of a portfolio of assets are equal to the weighted sum of the corresponding individual asset returns, with the weight of an asset being its relative weight(in purchase cost) in the portfolio.
#
# $$ R = \Sigma_{i=1}^{n}w_iR_i, \, r = \Sigma_{i=1}^{n}w_ir_i, \, \, where \, \Sigma_{i=1}^{n}w_i = 1 $$
#
# ### 6.2. Random Variables
# a. Random variables: a measurable function from a probability measure space
# b. Expected Value
# $$ \bar x = E(x) = \Sigma_{i=1}^{m}x_ip_i $$
# where $p_i$ is the probability that represents the relative chance of a occurance of $x_i$.
#
# c. Variance
# $$ var(y) = E[(y- \bar y)^2] = E[y^2] - E[y]^2 $$
# standard devidation: $ \sigma_y = \sqrt{E[(y- \bar y)^2]} $ <br/>
# d. Covariance
# $$ cov(x_1, x_2) = E[(x_1- \bar {x_1})(x_2- \bar {x_2})] = E[x_1x_2] - E[x_1]E[x_2] $$
# - If $\sigma_{12} = 0$ , uncorrelated
# - If $\sigma_{12} > 0$ , positively correlated
# - If $\sigma_{12} < 0$ , negatively correlated <br/>
#
# e. Correlation coefficient
# $$ \rho = \frac{\sigma_{12}}{\sigma_{1} \sigma_{2}}$$ <br/>
# f. $var(x+ y)= \sigma_{x}^2 + 2\sigma_{xy} + \sigma_{y}^2 $ <br/>
#
# ### 6.4. Portfolio Mean and Variance
# a. Mean Return of a Portfolio
# Suppose that there are n assets with random rates of return $r_1, r_2, ..., r_n$.These have expected values $E(r_i)= \bar {r_i}$, $i= 1,2, ..., n$. <br/>
# - The rate of return of the portfolio in terms of the return of the individual returns is
# $$ r = w_1r_1 + w_2r_2 + ... + w_nr_n $$
# - The expected value is
# $$ E(r) = w_1E(r_1) + w_2E(r_2) + ... + w_nE(r_n)$$
#
# b. Variance of Portfolio Return
# $$ \sigma^2 = E[(r- \bar r)^2] = E[(\Sigma_{i=1}^{n} w_ir_i- \Sigma_{i=1}^{n} w_i \bar {r_i})^2] = E[(\Sigma_{i,j=1}^{n} w_iw_j(r_i- \bar {r_i})(r_j- \bar {r_j})] = \Sigma_{i,j=1}^{n}w_iw_j\sigma_{ij}$$
#
# c.Diversification <br/>
# Portfolios with only a few assets may be subjected to a high degree of risk, represented by a relatively large variance. As general rule, the variance of the return of a portfolio can be reduced by including additional assets in the portfolio, a process referred to as diversification. This process reflects the maxim, "Don't put all your eggs in one basket."
#
# d.Diagram of a Portfolio <br/>
#
# Portfolio diagram lemma : The curve in an $\bar r - \sigma$ diagram defined by nonnegative mixtures of two assets 1 and 2 lies within the triangular region defined by the two original assets and the point on the vertical axis of height $A = \frac{\bar r_1 \sigma_2 + \bar r_2 \sigma_1}{\sigma_1 + \sigma_2}$. <br/>
#
# ### 6.5. The Feasible Set
# a. feasible set: THe set of points that correspond  to portfolios is called feasible set or feasible region <br/>
# b. Two properties in feasible set <br/>
# - 1. If there are at least three assets (not perfectly correlated and with different means), the feasible set will be a solid two-demensional region
# - 2. The feasible region is convex to the left <br/>
#
# c. The left boundary of a feasible set is called the 'minimum-variance set'. <br/>
# d. The minimum-variance set has a characteristic bullet shape. There is a special point on this set having minimum variance. It is termed the minimum-variance point(MVP).
#
# ### 6.6 The Markowitz Model
# a. The Markowitz Model <br/>
# Suppose that there are n assets with random rates of return $r_1, r_2, ..., r_n$.These have expected values $E(r_i)= \bar {r_i}$, $i= 1,2, ..., n$. And the covariances are $\sigma_{ij}$, for $i,j=1,2,...,n$. A portfolio is defined by a set of n weights $w_i, \, i = 1,2,...n$, that sum to 1.(We allow negative weights, corresponding to short selling).To find a minimum- variance portfolio, we fix the mean value at some arbitary value $\bar r$. Then, we find the feasible portfolio of minimum variance that has this mean. <br/>
#
# $$ minimize \, \frac{1}{2} \Sigma_{i,j=1}^{n} w_iw_j\sigma_{ij}$$
# $$ subject \, to \,\,\, \Sigma_{i=1}^{n} w_i \bar r_i = \bar r, \,\,\, \Sigma_{i=1}^{n} w_i = 1$$
#
# b. Solution of the Markowitz Problem
# Using Lagrange multipliers $\lambda$ and $\mu$, we form the Lagrangian (it is shown specifically at problem 3 in assignment 3).
# $$ L =  \frac{1}{2} \Sigma_{i,j=1}^{n} w_iw_j\sigma_{ij} - \lambda(\Sigma_{i=1}^{n} w_i \bar r_i - \bar r) - \mu(\Sigma_{i=1}^{n} w_i - 1)$$
#
# ### 6.7. The Two-Fund Theorem
# Two efficient funds(portfolios) can be established so that any efficient portfolio can be duplicated, in terms of means variance, as a combination of these two. In other words, all investors seeking efficient portfolios need only invest in combinations of these two funds.
#
# ### 6.9. The One-Fund Theorem
# There is a single fund F of risky assets such that any efficient protfolio can be constructed as a combination of the fudn F and the risk-free asset.

# %% [markdown]
# ## Assignment 2.
# Make a problem about the above subject.

# %% [markdown]
# (Shorting with margin) Suppose that to short a stock you are required to deposit an amount equal to the initial price $X_0$ of the stock. At the end of 1 year the stock price is $X_1$ and you liquidate your position. You receive your profit from shorting equal to $X_0 - X_1$ and your original deposit.If $R$ is the total return of the stock, what is the total return on your short?

# %% [markdown]
# Answer: Since i receive my profit from shorting equal to  𝑋0−𝑋 and my original deposit.The amount what I receive is $X_0 + X_0 - X_1$.
# Therefore, the toatla return is $\frac{2X_0 - X_1}{X_0}$.

# %% [markdown]
# ## Assignment 3.
# ## Problem 1.
# With the Coursera lecture: Introduction to Portfolio Construction and Analysis with Python, please replicate the code in the lab session of Week 2, An Introduction to Portfolio Optimization, and Week3, Beyond the Diversification.

# %% [markdown]
# ### Lab Session-Efficient frontier-Part 1
# # Efficient frontier

# %%
import pandas as pd
ind = pd.read_csv("C:/Users/honey/Desktop/Python/FBA Quant/Asset Pricing/week3/data/ind30_m_vw_rets.csv", header=0, index_col=0, parse_dates=True)/100

# %%
ind.head()
# Out:
#          Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 192607  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 192608  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 192609  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 192610 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 192611  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#          Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 192607  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 192608  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 192609  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 192610 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 192611  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#          Rtail   Meals   Fin     Other
# 192607  0.0007  0.0187  0.0037  0.0520
# ...

# %%
ind.index
# Out:
# Int64Index([192607, 192608, 192609, 192610, 192611, 192612, 192701, 192702,
#             192703, 192704,
#             ...
#             201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810,
#             201811, 201812],
#            dtype='int64', length=1110)

# %%
ind.index = pd.to_datetime(ind.index, format="%Y%m").to_period('M')

# %%
ind.head()
# Out:
#           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals   Fin     Other
# ...

# %%
ind.columns
# Out:
# Index(['Food ', 'Beer ', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth ',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal ', 'Oil  ', 'Util ', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin  ', 'Other'],
#       dtype='object')

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
ind.shape
# Out:
# (1110, 30)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import edhec_risk_kit as erk

# %%
ind = erk.get_ind_returns()
ind.shape
# Out:
# (1110, 30)

# %%
ind.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %%
erk.drawdown(ind["Food"])["Drawdown"].plot.line(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
cols_of_interest = ["Food","Smoke","Coal","Beer","Fin"]
erk.var_gaussian(ind[cols_of_interest], modified=True)
# Out:
# Food     0.061207
# Smoke    0.080292
# Coal     0.047359
# Beer     0.033881
# Fin      0.075199
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().tail()
# Out:
# Carry    0.094527
# Meals    0.098403
# BusEq    0.099377
# Games    0.100701
# Mines    0.102782
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().head()
# Out:
# Beer     0.033881
# Coal     0.047359
# Food     0.061207
# Telcm    0.064719
# Hshld    0.064886
# dtype: float64

# %%
erk.var_gaussian(ind, modified=True).sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
erk.sharpe_ratio(ind, 0.03, 12).sort_values().plot.bar(title ="Industry Sharpe Ratio 1926-2018", color="green")
# Out:
# <AxesSubplot:title={'center':'Industry Sharpe Ratio 1926-2018'}>

# %%
erk.sharpe_ratio(ind["2000":], 0.03, 12).sort_values().plot.bar(title ="Industry Sharpe Ratio 2000-2018",figsize=(12,5), color="goldenrod")
# Out:
# <AxesSubplot:title={'center':'Industry Sharpe Ratio 2000-2018'}>

# %%
er = erk.annualize_rets(ind["1995":"2000"], 12)

# %%
er.sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %%
cov = ind["1995":"2000"].cov()

# %%
cov.shape
# Out:
# (30, 30)

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.002287  0.002077  0.001757  0.000701  0.000886  0.001208  0.001474
# Beer   0.002077  0.004599  0.001143  0.001147  0.000765  0.002447  0.001415
# Smoke  0.001757  0.001143  0.007130  0.000296 -0.000099  0.000981  0.000761
# Games  0.000701  0.001147  0.000296  0.003271  0.001485  0.001018  0.001814
# Books  0.000886  0.000765 -0.000099  0.001485  0.002302  0.000876  0.002037
# Hshld  0.001208  0.002447  0.000981  0.001018  0.000876  0.002849  0.001046
# Clths  0.001474  0.001415  0.000761  0.001814  0.002037  0.001046  0.004896
# Hlth   0.001105  0.001689  0.000877  0.001219  0.000657  0.001253  0.000759
# Chems  0.001253  0.001292  0.000687  0.001547  0.001559  0.001226  0.002547
# Txtls  0.001021  0.001721  0.000555  0.001291  0.001362  0.001172  0.002105
# Cnstr  0.001282  0.001945  0.001181  0.001723  0.001531  0.001770  0.002486
# ...

# %% [markdown]
# ### Lab Session-Efficient frontier-Part 2
# # Efficient frontier part II

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"], 12)
cov = ind["1996":"2000"].cov()

# %%
def portfolio_return(weights, returns):
    """
    Weights -> Returns
    """
    return weights.T @ returns

def portfolio_vol(weights, covmat):
    """
    Weights -> Vol
    """
    return (weights.T @ covmat @ weights)**0.5

# %%
l = ["Food","Beer","Smoke","Coal"]
er[l]
# Out:
# Food     0.116799
# Beer     0.141126
# Smoke    0.107830
# Coal     0.414689
# dtype: float64

# %%
cov.loc[l,l]
# Out:
#            Food      Beer     Smoke      Coal
# Food   0.002609  0.002379  0.002061  0.000027
# Beer   0.002379  0.005264  0.001359  0.001728
# Smoke  0.002061  0.001359  0.008349 -0.000733
# Coal   0.000027  0.001728 -0.000733  0.018641

# %%
import numpy as np
weights = np.repeat(1/4, 4)
erk.portfolio_return(weights, er[l])
# Out:
# 0.19511097196038385

# %%
weights
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
erk.portfolio_vol(weights, cov.loc[l,l])
# Out:
# 0.055059195776437045

# %% [markdown]
# ## 2 Asset Frontier

# %%
l = ["Games", "Fin"]

# %%
n_points = 20
weights = [np.array([w, 1-w]) for w in np.linspace(0,1, n_points)]
weights
# Out:
# [array([0., 1.]),
#  array([0.05263158, 0.94736842]),
#  array([0.10526316, 0.89473684]),
#  array([0.15789474, 0.84210526]),
#  array([0.21052632, 0.78947368]),
#  array([0.26315789, 0.73684211]),
#  array([0.31578947, 0.68421053]),
#  array([0.36842105, 0.63157895]),
#  array([0.42105263, 0.57894737]),
#  array([0.47368421, 0.52631579]),
#  array([0.52631579, 0.47368421]),
#  array([0.57894737, 0.42105263]),
#  array([0.63157895, 0.36842105]),
#  array([0.68421053, 0.31578947]),
#  array([0.73684211, 0.26315789]),
#  array([0.78947368, 0.21052632]),
#  array([0.84210526, 0.15789474]),
#  array([0.89473684, 0.10526316]),
#  array([0.94736842, 0.05263158]),
#  array([1., 0.])]

# %%
len(weights)
# Out:
# 20

# %%
l
# Out:
# ['Games', 'Fin']

# %%
rets = [erk.portfolio_return(w, er[l]) for w in weights]
vols = [erk.portfolio_vol(w, cov.loc[l,l]) for w in weights]
import pandas as pd
ef = pd.DataFrame({"R": rets, "Vol": vols})
ef.plot.scatter(x="Vol", y="R")
# Out:
# <AxesSubplot:xlabel='Vol', ylabel='R'>

# %%
l = ["Fin","Beer"]
erk.plot_ef2(25, er[l], cov.loc[l,l], style = ".")
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# ### Lab Session-Applying Quadprog to Draw the Efficient Frontier
# # N -Asset Efficient Frontier

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk

ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"], 12)
cov = ind["1996":"2000"].cov()

# %% [markdown]
# ```python
# def plot_ef(n_points, er, cov, style=".-"):
#     """
#     Plots the N-assets efficient frontier
#     """
#     weights = minimize_vol(target_return)?????
#     rets = [portfolio_return(w,er) for w in weights]
#     vols = [portfolio_vol(w, cov) for w in weights]
#     ef = pd.DataFrame({
#         "Returns": rets,
#         "Volatility": vols
#     })
#     return ef.plot.line(x="Volatility", y="Returns", style= style)
# ```

# %%
from scipy.optimize import minimize

# %%
l = ["Games", "Fin"]
erk.plot_ef2(20, er[l], cov.loc[l,l], style= ".-")
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
import numpy as np

def minimize_vol(target_return, er, cov):
    """
    target_ret -> W
    """
    n = er.shape[0]
    init_guess = np.repeat(1/n, n)
    bounds = ((0.0, 1.0),)*n
    return_is_target = {
        'type': 'eq',
        'args': (er,),
        'fun': lambda weights, er: target_return - erk.portfolio_return(weights, er)
    }
    weights_sum_to_1 = {
        'type': 'eq',
        'fun': lambda weights: np.sum(weights) -1 
    }
    results = minimize(erk.portfolio_vol, init_guess,
                       args=(cov,), method="SLSQP",
                       options={'disp':False},
                       constraints=(return_is_target, weights_sum_to_1),
                       bounds=bounds
                      )
    return results.x

# %%
l
# Out:
# ['Games', 'Fin']

# %%
w15 = erk.minimize_vol(0.15, er[l], cov.loc[l,l])
vol15 = erk.portfolio_vol(w15, cov.loc[l,l])
vol15
# Out:
# 0.056163669406706564

# %%
w15
# Out:
# array([0.47287631, 0.52712369])

# %%
import pandas as pd
def optimal_weights(n_points, er, cov):
    """
    -> list of weights to run the optimizer on to minimize the vol
    """
    target_rs = np.linspace(er.min(), er.max(), n_points)
    weights = [minimize_vol(target_return, er, cov)for target_return in target_rs]
    return weights
    
def plot_ef(n_points, er, cov):
    """
    Plots the N-assets efficient frontier
    """
    weights = optimal_weights(n_points, er, cov)
    rets = [erk.portfolio_return(w,er) for w in weights]
    vols = [erk.portfolio_vol(w, cov) for w in weights]
    ef = pd.DataFrame({
        "Returns": rets,
        "Volatility": vols
    })
    return ef.plot.line(x="Volatility", y="Returns", style= ".-")

# %%
l = ["Smoke", "Fin", "Games", "Coal"]
plot_ef(25, er[l], cov.loc[l,l])
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
l = ["Smoke", "Fin", "Games", "Coal"]
erk.plot_ef(25, er[l], cov.loc[l,l])
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# ### Lab Session-Locating the Max Sharpe Ratio Portfolio
# # Finding the Max Sharpe Ratio Portfolio!

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk

ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"], 12)
cov = ind["1996":"2000"].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ```python
# from scipy.optimize import minimize
# def msr(riskfree_rate, er, cov):
#     """
#     RiskFree rate + ER + COV -> W
#     """
#     n = er.shape[0]
#     init_guess = np.repeat(1/n, n)
#     bounds = ((0.0, 1.0),)*n
#     weights_sum_to_1 = {
#         'type': 'eq',
#         'fun': lambda weights: np.sum(weights) -1
#     }
#     def neg_sharpe_ratio(weights, riskfree_rate, er, cov):
#         """
#         Returns of negative of the sharpe ratio, given weights
#         """
#         r = erk.portfolio_return(weight, er)
#         vol = erk.portolio_vol(weights, cov)
#         return -(r - riskfree_rate)/vol
#
#     results = minimize(neg_sharpe_ratio, init_guess,
#                        args=(cov,), method="SLSQP",
#                        options={'disp':False},
#                        constraints=(weights_sum_to_1),
#                        bounds=bounds
#                       )
#     return results.x
# ```

# %%
from scipy.optimize import minimize
def msr(riskfree_rate, er, cov):
    """
    RiskFree rate + ER + COV -> W
    """
    n = er.shape[0]
    init_guess = np.repeat(1/n, n)
    bounds = ((0.0, 1.0),)*n
    weights_sum_to_1 = {
        'type': 'eq',
        'fun': lambda weights: np.sum(weights) -1 
    }
    def neg_sharpe_ratio(weights, riskfree_rate, er, cov):
        """
        Returns of negative of the sharpe ratio, given weights
        """
        r = erk.portfolio_return(weights, er)
        vol = erk.portfolio_vol(weights, cov)
        return -(r - riskfree_rate)/vol

    results = minimize(neg_sharpe_ratio, init_guess,
                       args=(riskfree_rate, er, cov,), method="SLSQP",
                       options={'disp':False},
                       constraints=(weights_sum_to_1),
                       bounds=bounds
                      )
    return results.x

# %%
ax = erk.plot_ef(20, er, cov)
ax.set_xlim(left = 0)
rf = 0.1
w_msr = msr(rf, er, cov)
r_msr = erk.portfolio_return(w_msr, er)
vol_msr = erk.portfolio_vol(w_msr, cov)
# Add CML
cml_x = [0, vol_msr]
cml_y = [rf, r_msr]
ax.plot(cml_x, cml_y, color="green", marker="o", linestyle="dashed")

# %%
erk.plot_ef(20, er, cov, show_cml =True, riskfree_rate = 0.1)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# ### Lab Session-Plotting EW and GMV on the Efficient Frontier
# # Lack of Robustness of the Markowitz Procedure, and the GMV

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk
import numpy as np

ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"], 12)
cov = ind["1996":"2000"].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
l =["Food", 'Steel']
erk.msr(0.1, er[l], cov.loc[l,l])
# Out:
# array([0.75040363, 0.24959637])

# %%
er[l]
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %%
erk.msr(0.1, np.array([.11,.12]), cov.loc[l,l])
# Out:
# array([0.57930354, 0.42069646])

# %%
erk.msr(0.1, np.array([.10,.13]), cov.loc[l,l])
# Out:
# array([0., 1.])

# %%
erk.msr(0.1, np.array([.13,.10]), cov.loc[l,l])
# Out:
# array([1., 0.])

# %%
erk.plot_ef(20, er, cov, show_cml =True, riskfree_rate = 0.1, show_ew=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
erk.plot_ef(20, er, cov, show_cml =True, riskfree_rate = 0.1, show_ew=True, show_gmv=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# ### Lab Session-Limits of Diversification-Part1
# # Limits of Diversification
# (incl the anatomy of a cap-weighted portfolio, and a bunch of cool Pandas stuff along the way)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk
import pandas as pd
import numpy as np

ind_return = erk.get_ind_returns()
ind_nfirms = erk.get_ind_nfirms()
ind_size = erk.get_ind_size()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind_return.shape
# Out:
# (1110, 30)

# %%
ind_nfirms.shape
# Out:
# (1110, 30)

# %%
ind_size.shape
# Out:
# (1110, 30)

# %%
ind_nfirms.head()
# Out:
#          Food  Beer  Smoke  Games  Books  Hshld  Clths  Hlth  Chems  Txtls  \
# 1926-07    43     3     16      7      2      8     12     7     17     13
# 1926-08    43     3     16      7      2      8     12     7     17     13
# 1926-09    43     3     16      7      2      8     12     7     17     13
# 1926-10    43     3     16      7      2      8     12     7     17     13
# 1926-11    43     3     16      7      2      8     12     7     17     13
#
#          ...  Telcm  Servs  BusEq  Paper  Trans  Whlsl  Rtail  Meals  Fin  \
# 1926-07  ...      5      3      7      6     74      2     33      6   12
# 1926-08  ...      5      3      7      6     74      2     33      6   12
# 1926-09  ...      5      3      7      6     74      2     33      6   12
# 1926-10  ...      5      3      7      6     74      2     33      6   12
# 1926-11  ...      5      3      7      6     74      2     33      6   12
#
#          Other
# 1926-07      4
# 1926-08      4
# 1926-09      4
# ...

# %%
ind_mktcap = ind_nfirms * ind_size
ind_mktcap.shape
# Out:
# (1110, 30)

# %%
total_mktcap = ind_mktcap.sum(axis = "columns")

# %%
total_mktcap.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
ind_capweight = ind_mktcap.divide(total_mktcap, axis="rows")

# %%
ind_capweight.head()
# Out:
#              Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# 1926-07  0.058037  0.000801  0.035844  0.006935  0.000902  0.006683  0.008265
# 1926-08  0.056578  0.000738  0.035264  0.006932  0.000972  0.006453  0.008673
# 1926-09  0.056699  0.000917  0.036510  0.006810  0.001046  0.006038  0.008249
# 1926-10  0.056920  0.000954  0.036736  0.007175  0.001028  0.006053  0.008139
# 1926-11  0.056725  0.000951  0.038285  0.007047  0.001161  0.005924  0.008396
#
#              Hlth     Chems     Txtls  ...     Telcm     Servs     BusEq  \
# 1926-07  0.006701  0.036726  0.003014  ...  0.065714  0.001531  0.014889
# 1926-08  0.006583  0.038497  0.002938  ...  0.064380  0.001613  0.014732
# 1926-09  0.006668  0.039700  0.003109  ...  0.064318  0.001609  0.014870
# 1926-10  0.006704  0.041486  0.003160  ...  0.064896  0.001636  0.014850
# 1926-11  0.006831  0.040665  0.003269  ...  0.066868  0.001642  0.015118
#
# ...

# %%
ind_capweight.loc["1926"].sum(axis="columns")
# Out:
# 1926-07    1.0
# 1926-08    1.0
# 1926-09    1.0
# 1926-10    1.0
# 1926-11    1.0
# 1926-12    1.0
# Freq: M, dtype: float64

# %%
ind_capweight[["Fin","Steel"]].plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
total_market_return = (ind_capweight*ind_return).sum(axis="columns")

# %%
total_market_return.plot()
# Out:
# <AxesSubplot:>

# %%
total_market_index = erk.drawdown(total_market_return).Wealth
total_market_index.plot(figsize=(10,5), title = "Total Market Capweight Index 1926-2018")
# Out:
# <AxesSubplot:title={'center':'Total Market Capweight Index 1926-2018'}>

# %%
total_market_index["1980":].plot(figsize=(12,6))
total_market_index["1980":].rolling(window=36).mean().plot()
# Out:
# <AxesSubplot:>

# %%
tmi_tr36rets = total_market_return.rolling(window=36).aggregate(erk.annualize_rets, periods_per_year = 12)
tmi_tr36rets.plot(figsize=(12,6), label="Tr36 mo Return", legend=True)
#total_market_return.plot(label="Returns", legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Rolling Correlation - along with MultiIndex and .groupby

# %%
ts_corr = ind_return.rolling(window=36).corr()
ts_corr.tail()
# Out:
#                    Food      Beer     Smoke     Games     Books     Hshld  \
# 2018-12 Whlsl  0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail  0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals  0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin    0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other  0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                   Clths      Hlth     Chems     Txtls  ...     Telcm  \
# 2018-12 Whlsl  0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail  0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals  0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin    0.425899  0.658468  0.760151  0.577090  ...  0.420863
#         Other  0.467099  0.645035  0.712511  0.520953  ...  0.607868
#
#                   Servs     BusEq     Paper     Trans     Whlsl     Rtail  \
# ...

# %%
ind_return.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %%
ts_corr.index.names = ['date', 'industry']
ts_corr.tail()
# Out:
#                       Food      Beer     Smoke     Games     Books     Hshld  \
# date    industry
# 2018-12 Whlsl     0.474948  0.356983  0.122672  0.510425  0.803362  0.419280
#         Rtail     0.517856  0.406107  0.030283  0.676464  0.636320  0.358336
#         Meals     0.370187  0.385483  0.122007  0.301516  0.520649  0.308216
#         Fin       0.298823  0.192706  0.027593  0.480276  0.694812  0.162690
#         Other     0.436952  0.376565  0.224010  0.331829  0.558072  0.390610
#
#                      Clths      Hlth     Chems     Txtls  ...     Telcm  \
# date    industry                                          ...
# 2018-12 Whlsl     0.570071  0.739764  0.785796  0.634197  ...  0.648092
#         Rtail     0.676598  0.714933  0.626034  0.634202  ...  0.562238
#         Meals     0.302176  0.416193  0.520023  0.491726  ...  0.406184
#         Fin       0.425899  0.658468  0.760151  0.577090  ...  0.420863
# ...

# %%
ind_tr36corr = ts_corr.groupby(level='date').apply(lambda cormat: cormat.values.mean())

# %%
ind_tr36corr.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
tmi_tr36rets.plot(label="Tr36 Mo Rets", figsize=(12,6),legend=True)
ind_tr36corr.plot(label="Tr36 Mo Corr", legend=True, secondary_y=True)
# Out:
# <AxesSubplot:>

# %%
tmi_tr36rets.corr(ind_tr36corr)
# Out:
# -0.28010065062884026

# %% [markdown]
# ### Lab Session-CPPI and Drawdown
# # Implementing Portfolio Insurance (CPPI) and Drawdown Constraints

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk
import pandas as pd
import numpy as np

# Load the industry returns and the total market index we previously created
ind_return = erk.get_ind_returns()
tmi_return = erk.get_total_market_index_returns()

# %%
risky_r = ind_return["2000":][["Steel","Fin","Beer"]]
# Safe Asset

# %%
risky_r.shape
# Out:
# (228, 3)

# %%
safe_r = pd.DataFrame().reindex_like(risky_r)

# %%
safe_r.shape
# Out:
# (228, 3)

# %%
safe_r[:] = 0.03/12
start = 1000
floor = 0.8

# %% [markdown]
# 1. Cushion - (Asset Value minus Floor Value)
# 2. Compute an Allocation to Safe and Risky Assets $\to$ m $\times$ budget
# 3. Recompute the Asset Value based on the returns

# %%
def compound1(r):
    return (1+r).prod()-1

def compound2(r):
    return np.expm1(np.log1p(r).sum())

# %%
compound1(risky_r)
# Out:
# Steel   -0.051696
# Fin      1.773937
# Beer     3.361349
# dtype: float64

# %%
compound2(risky_r)
# Out:
# Steel   -0.051696
# Fin      1.773937
# Beer     3.361349
# dtype: float64

# %%
# %timeit compound1(risky_r)
# Out:
# 555 µs ± 19.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit compound2(risky_r)
# Out:
# 555 µs ± 64.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# # Back to CPPI

# %%
dates = risky_r.index
n_steps = len(dates)
account_value = start
floor_value = start*floor
m = 3
account_history = pd.DataFrame().reindex_like(risky_r)
cushion_history = pd.DataFrame().reindex_like(risky_r)
risky_w_history = pd.DataFrame().reindex_like(risky_r)

for step in range(n_steps):
    cushion = (account_value - floor_value)/account_value
    risky_w = m*cushion
    risky_w = np.minimum(risky_w,1)
    risky_w = np.maximum(risky_w,0)
    safe_w = 1 - risky_w
    risky_alloc = account_value*risky_w
    safe_alloc = account_value*safe_w
    ## update the account value for this time step
    account_value = risky_alloc*(1+risky_r.iloc[step]) + safe_alloc*(1+safe_r.iloc[step])
    # save the value so I can look at the history and plot it etc
    cushion_history.iloc[step] = cushion
    risky_w_history.iloc[step] = risky_w
    account_history.iloc[step] = account_value

# %%
account_history.head()
# Out:
#                Steel          Fin        Beer
# 2000-01   984.380000   974.480000  987.320000
# 2000-02  1023.292876   931.167544  922.971256
# 2000-03  1047.555176   998.187296  924.835988
# 2000-04  1042.079009   973.927479  939.993701
# 2000-05  1007.137753  1001.460033  991.145489

# %%
risky_wealth = start*(1+risky_r).cumprod()
risky_wealth.plot()
# Out:
# <AxesSubplot:>

# %%
ax = account_history["Beer"].plot(figsize=(12,6))
risky_wealth["Beer"].plot(ax=ax, style="k:")
ax.axhline(y=floor_value, color='r', linestyle="--")

# %%
risky_w_history.plot()
# Out:
# <AxesSubplot:>

# %%
ind = "Fin"
ax = account_history[ind].plot(figsize=(12,6))
risky_wealth[ind].plot(ax=ax, style="k:")
ax.axhline(y=floor_value, color='r', linestyle="--")

# %%
ind = "Steel"
ax = account_history[ind].plot(figsize=(12,6))
risky_wealth[ind].plot(ax=ax, style="k:")
ax.axhline(y=floor_value, color='r', linestyle="--")

# %%
erk.summary_stats(risky_r)
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.002790        0.312368 -0.326334  4.144381
# Fin             0.055166        0.192909 -0.533218  4.995534
# Beer            0.080598        0.138925 -0.493545  4.173881
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.150139            0.208117     -0.102567     -0.758017
# Fin                   0.091224            0.132175      0.126718     -0.718465
# Beer                  0.063015            0.091442      0.354314     -0.271368

# %%
btr = erk.run_cppi(risky_r)
erk.summary_stats(btr["Wealth"].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# Steel          -0.005167        0.174180 -1.995143  17.110190
# Fin             0.040894        0.131678 -0.946504   6.051414
# Beer            0.075544        0.115462 -0.669250   4.760879
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.091995            0.130153     -0.196750     -0.655198
# Fin                   0.065535            0.091621      0.080352     -0.549673
# Beer                  0.052923            0.074908      0.383772     -0.259582

# %%
btr = erk.run_cppi(tmi_return["2007":])
ax = btr["Wealth"].plot(figsize=(12,6), legend= False)
btr["Risky Wealth"].plot(ax=ax, style="k--", legend= False)
# Out:
# <AxesSubplot:>

# %%
erk.summary_stats(btr["Risky Wealth"].pct_change().dropna())
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# R           0.073411        0.150463 -0.734939  4.523488
#
#    Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# R                 0.071592            0.096315      0.280618     -0.499943

# %%
erk.summary_stats(btr["Wealth"].pct_change().dropna())
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# R           0.069416        0.100381 -0.588292  3.740932
#
#    Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# R                 0.045678            0.062953      0.382052     -0.229683

# %% [markdown]
# # Drawdown Constraint

# %%
btr = erk.run_cppi(ind_return["2007":][["Steel","Fin","Beer"]], drawdown = 0.25)

# %%
ax = btr["Wealth"].plot(figsize=(12,6))
btr["Risky Wealth"].plot(ax=ax, style="--")
# Out:
# <AxesSubplot:>

# %%
erk.summary_stats(btr["Risky Wealth"].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel          -0.039660        0.306407 -0.459951  4.782828
# Fin             0.027364        0.212204 -0.695200  4.621401
# Beer            0.111554        0.127971 -0.670797  4.650878
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.152288            0.203837     -0.221642     -0.758017
# Fin                   0.105744            0.149862     -0.012370     -0.718465
# Beer                  0.056497            0.077388      0.620132     -0.271368

# %%
erk.summary_stats(btr["Wealth"].pct_change().dropna())
# Out:
#        Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Steel           0.003784        0.097073 -0.441089  5.220481
# Fin             0.041975        0.085028 -0.355163  4.153860
# Beer            0.084375        0.086263 -0.744111  4.571533
#
#        Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# Steel                 0.047371            0.066991     -0.262958     -0.248059
# Fin                   0.038342            0.054111      0.136964     -0.243626
# Beer                  0.037937            0.051189      0.613413     -0.161186

# %% [markdown]
# ### Lab Session-Random Walks and Monte Carlo
# # Random Walk Generation
#
# $$ \frac{S_{t+dt}-S_t}{S_t} = \mu dt + \sigma\sqrt{dt}\xi_t$$

# %%
import numpy as np

def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evloution of a Stock Price using a Geomertic Brownian Motion Model 
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
p = gbm(10, n_scenarios=3)

# %%
p.shape
# Out:
# (120, 3)

# %%
p.head()
# Out:
#             0           1          2
# 0  106.750100  100.404332  98.345407
# 1  100.780889   98.338682  91.080050
# 2  105.667485  106.553803  92.351185
# 3  101.125332  111.586749  91.572821
# 4  104.514875  111.848830  99.344300

# %%
p.plot()
# Out:
# <AxesSubplot:>

# %%
p = gbm(n_years=10, n_scenarios=1000).plot(figsize=(12,6), legend=False)

# %%
def gbm0(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evloution of a Stock Price using a Geomertic Brownian Motion Model 
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

def gbm1(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evloution of a Stock Price using a Geomertic Brownian Motion Model 
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    # to prices
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
# %timeit gbm0(n_years=5, n_scenarios=1000)
# Out:
# 2.99 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit gbm1(n_years=5, n_scenarios=1000)
# Out:
# 2.68 ms ± 107 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
gbm(n_years=10, n_scenarios=20).plot(legend=False, figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
def gbm(n_years=10, n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """
    Evloution of a Stock Price using a Geomertic Brownian Motion Model 
    """
    dt = 1/steps_per_year
    n_steps = int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    rets_plus_1[0] = 1
    # to prices
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
gbm(n_scenarios=10).head()
# Out:
#             0           1           2           3           4           5  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  101.751757   97.393586  109.678506  101.888196   94.743549  105.879194
# 2  112.259393  100.044522  105.949037  101.701460   88.461811  108.835044
# 3  114.532418   99.189248  107.279492   95.865456   90.175862  114.885162
# 4  106.163988  108.691083  110.587651   98.522464   92.564623  114.308834
#
#             6           7           8           9
# 0  100.000000  100.000000  100.000000  100.000000
# 1   93.762305   90.979382  105.434835  100.208262
# 2   89.915153   90.435389  108.660915  112.395482
# 3   90.999844   91.267861  106.841857  114.032333
# 4   87.178505   91.461443  111.360789  108.541806

# %% [markdown]
# ## Problem 2.
# There are two risky assets, $A_1,A_2$ such that
# - expected returns of A and B:  $μ_1,μ_2 $
# - standard deviations of A and B: $σ_1,σ_2 $
#
# Thus, we can construct the portfolio $P=w_1 A+w_2 B$ ($w_1,w_2$ are the weights of risky assets) with these two risky assets.
# Using the Lagrange Multiplier Method, find the analytical solution of the efficient frontier.

# %% [markdown]
# #### Hint:
#
# When the target expected return is given as $μ_0$<br/>
# Constraints: 1. $w_1 μ_1+w_2 μ_2=μ_0,$ 2. $w_1+w_2=1$<br/>
# Step1. Construct Lagrange Function under the given rate $μ_0$ <br/>
# $$ L= \frac{1}{2} ∑_{i,j=1}^2 w_i w_j σ_{ij} -λ_1 (∑_{i=1}^2w_i μ_i-μ_0 )-λ_2 (∑_{i=1}^2w_i-1) $$
# Step2.  Find the Optimal weights written by lambda after Partial Differentiation <br/>
# $$ \frac{∂L}{∂w_1 }=0,\frac{∂L}{∂w_2 }=0 → optimal \, weights \, w^*  \,(function\,of\, λ_1,\,λ_2) $$ <br/>
# Step3. Apply Optimal weight $w^*$ obtained in the Step2 to constraints, and then find the analytical solution of $w^*$. <br/>
# Step4. Derive minimum standard deviation of portfolio in given expected return $μ_0$ by using the optimal weight $w^*$.

# %% [markdown]
# ### Solution
#
# - Step 1. Construct Lagrange Function under the given rate $\mu_0$
# $$ minimize \, \frac{1}{2} \Sigma_{i,j=1}^{2} w_iw_j\sigma_{ij}$$
# $$ subject \, to \,\,\, \Sigma_{i=1}^{2} w_i \bar r_i = \bar r, \,\,\, \Sigma_{i=1}^{2} w_i = 1$$
#
# $$ L= \frac{1}{2} ∑_{i,j=1}^2 w_i w_j σ_{ij} -λ_1 (∑_{i=1}^2w_i μ_i-μ_0 )-λ_2 (∑_{i=1}^2w_i-1) $$
# $$ \to L= \frac{1}{2}({w_1}^2{σ_{1}}^2 +2w_1w_2σ_{12}+{w_2}^2{σ_{2}}^2) -λ_1 (w_1 μ_1 +w_2 μ_2 -μ_0 )-λ_2 (w_1+w_2 -1) $$
# $where \,\, \sigma_{12} = \sigma_{21}$.
#
# - Step2. Find the Optimal weights written by lambda after Partial Differentiation <br/>
# $ \frac{∂L}{∂w_1 }= \frac{1}{2}(2w_1{σ_{1}}^2 + 2w_2σ_{12})-λ_1μ_1 - λ_2=0 $  <br/>
# $ \frac{∂L}{∂w_2 }= \frac{1}{2}(2w_2{σ_{2}}^2 + 2w_1σ_{12})-λ_1μ_2 - λ_2=0 $  <br/>
#
# Rewrite the above equations, <br/>
# $$ w_1{σ_{1}}^2 + w_2σ_{12}-λ_1μ_1 - λ_2=0 \,\,\,\,(A)$$
# $$ w_2{σ_{2}}^2 + w_1σ_{12}-λ_1μ_2 - λ_2=0 \,\,\,\,(B)$$
#
# Using (A) and (B), we can derive optimal $w^*$.
#
# $$ {w_1}^* = \frac{(\mu_1{\sigma_2}^2 - \mu_2 \sigma_{12})\lambda_1 + ({\sigma_2}^2 - \sigma_{12})\lambda_2}{{\sigma_1}^2{\sigma_2}^2-{\sigma_{12}}^2}$$
# $$ {w_2}^* = \frac{(\mu_2 {\sigma_1}^2 - \mu_1\sigma_{12})\lambda_1 + ({\sigma_1}^2 - \sigma_{12})\lambda_2}{{\sigma_1}^2{\sigma_2}^2-{\sigma_{12}}^2}$$
#
# - Step3. Apply Optimal weight $w^*$ obtained in the Step2 to constraints, and then find the analytical solution of $w^*$. <br/>
#
# Let $A=(\mu_1{\sigma_2}^2 - \mu_2 \sigma_{12})$, $B={\sigma_2}^2 - \sigma_{12}$, $C=\mu_2 {\sigma_1}^2 - \mu_1\sigma_{12}$, $D={\sigma_1}^2 - \sigma_{12}$, $E={\sigma_1}^2{\sigma_2}^2-{\sigma_{12}}^2$.
#
# Rewrite the constraints uisng A,B,C,D and E,
#
# $ w_1 + w_2 = 1 \to (A+C)\lambda_1 + (B+D)\lambda_2 = E $ <br/>
# $ w_1\mu_1 + w_2\mu_2 = \mu_0 \to (A\mu_1+C\mu_2)\lambda_1 + (B\mu_1+D\mu_2)\lambda_2= E\mu_0 $
#
# Solving for $\lambda_1$ and $\lambda_2$,
# $${\lambda_1}^* = \frac{E[B(\mu_1 - \mu_0)+D(\mu_2 - \mu_0)]}{(AD-BC)(\mu_2-\mu_1)} $$
# $${\lambda_2}^* = \frac{-E[A(\mu_1 - \mu_0)+C(\mu_2 - \mu_0)]}{(AD-BC)(\mu_2-\mu_1)}$$
#
# Since ${w_1}^*$ and ${w_2}^*$ is
# $$ {w_1}^* = \frac{A\lambda_1 + B\lambda_2}{E} {w_2}^* = \frac{C\lambda_1 + D\lambda_2}{E} $$
#
# Substituting ${\lambda_1}$, ${\lambda_2}$ with ${\lambda_1}^*$, ${\lambda_1}^*$,
#
# $$ {w_1}^* = \frac{A{\lambda_1}^* + B{\lambda_2}^*}{E} = \frac{\mu_2 - \mu_0}{\mu_2 - \mu_1}$$
# $$ {w_2}^* = \frac{C{\lambda_1}^* + D{\lambda_2}^*}{E} = \frac{\mu_0 - \mu_1}{\mu_2 - \mu_1}$$
#
#
# - Step4. Derive minimum standard deviation of portfolio in given expected return $μ_0$ by using the optimal weight $w^*$.
#
# The standard deviation at the solution is $\sqrt{{w_1}^2{σ_{1}}^2 +2w_1w_2σ_{12}+{w_2}^2{σ_{2}}^2}$.
# $$ \sigma_{min} = \frac{\sqrt{(\mu_2 - \mu_0)^2{\sigma_1}^2 +2(\mu_2 - \mu_0)(\mu_0 - \mu_1)\sigma_{12}+(\mu_0 - \mu_1)^2{\sigma_2}^2}}{\mu_2 - \mu_1}$$

# %% [markdown]
# ## Problem 3.
# Jin’s friend is planning to invest \\$1 million in a rock concert to be held 1 year from now. The friend figures that he will obtain \\$3 million revenue from his \\$1 million investment-unless, my goodness, it rains. If it rains, he will lose his entire investment. There is a 50% chance that it will rain the day of the concert. Gain suggests that he buy rain insurance. He can buy one unit of insurance for \\$0.5. and this unit pays \\$1 if it rains and nothing if it does not. He may purchase as many as he wishes, up to \\$3 million.<br/>
# a) What is the expected rate of return on his investment if he buys $u$ units of insurance? (The cost of insurance is in addition to his \\$1 million investment.)

# %% [markdown]
# ### Solution
# Expected rate of return = $\frac{amount\,received - amount\,invested}{amount\,invested}$
#
# Expected amount received = $0.5(3,000,000) + 0.5u = 1,500,000 + 0.5u $ <br/>
# Amount invested = $1,000,000 + 0.5u$<br/>
# $E(r) = \frac{1,500,000 + 0.5u - 1,000,000 - 0.5u}{1,000,000 + 0.5u}$ <br/>
# $\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,= \frac{500,000}{1,000,000 + 0.5u}$

# %% [markdown]
# b) What number of units will minimize the variance of his return? What is this minimum value? And what is the corresponding expected rate of return? <br/>
# Hint: Before calculating a general expression for variance, think about a simple answer.

# %% [markdown]
# ### Solution
# To make minimize variance, make a same amount of returns at any situations. That makes the vairance zero.
#
# If there is no rain, the amount of return is $3,000,000 - 1,000,000 - 0.5u$.
# If there is rain, the amount of return is $0 - 1,000,000 - 0.5u + u$.
#
# $3,000,000 - 1,000,000 - 0.5u = 0 - 1,000,000 - 0.5u + u$
# $\therefore u = 3,000,000$
#
# - the minimum variance = 0
# - this minimum value = \\$500,000 ($\because$ buy 3 million units of insurance)
# - expected rate of return = $\frac{500,000}{1,000,000 + 0.5u} = \frac{500,000}{2,500,000} = 20\% $
