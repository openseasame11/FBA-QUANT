# %% [markdown]
# ## Assingment.1

# %% [markdown]
# #### Chap 7. Optimtimal Risky Portfolio
# 1. The expected return of a portfolio is the weighted average of the component security expected returns with the investment proportions as weights.
# 2. The variance of a portfolio is the weighted sum of the elements of the covariance matrix with the product of the investment proportions as weights.
# Thus the variance of each asset is weighted by the square of its investment proportion. The covariance of each pair of assets appears twice in the covariance matrix; thus the portfolio variance includes twice each covariance weighted by the product of the investment proportions in each of the two assets.
# 3. Even if the covariances are positive, the portfolio standard deviation is less than the weighted average of the component standard deviations, as long as the assets are not perfectly positively correlated. Thus, portfolio diversification is of value as long as assets are less than perfectly correlated.
# 4. The greater an asset's covariance with the other assets in the portfolio, the more it contributes to portfolio variance.
#  ***An asset that is perfectly negatively correlated with a portfolio can serve as a perfect hedge. That perfect hedge asset can reduce the portfolio variance to zero.***
# 5. The efficient frontier is the graphical representation of a set of portfolios that *maximize expected return for each level of portfolio risk*. Rational investors will choose a portfolio on the efficient frontier.
# 6. A portfolio manager identifies the efficient frontier by first establishing estimates for asset expected returns and the covariance matrix. This input list is then fed into an optimization program that produces as outputs the investment proportions, expected returns, and standard deviations of the portfolios on the efficient frontier.
# 7. In general, portfolio managers will arrive at different efficient portfolios because of differences in methods and quality of security analysis. Managers compete on the quality of their security analysis relative to their management fees.
# 8. If a risk-free asset is available and input lists are identical, all investors will choose the same portfolio on the efficient frontier of risky assets: ***the portfolio tangent to the CAL.***
# All investors with identical input lists will hold an identical risky portfolio, differing only in how much each allocates to this optimal portfolio and to the risk-free asset. This result is characterized as the separation principle of portfolio construction.
# 9. Diversification is based on the allocation of a portfolio of fixed size across several assets, limiting the exposure to any one source of risk.
# Adding additional risky assets to a portfolio, thereby increasing the total amount invested, does not reduce dollar risk, even if it makes the rate of return more predictable. This is because that ***uncertainty is applied to a larger investment base.*** Nor does investing over longer horizons reduce risk.
#  ***Increasing the investment horizon is analogous to investing in more assets.***
# It increases total risk. Analogously, the key to the insurance industry is risk sharing—the spreading of many independent sources of risk across many investors, each of whom takes on only a small exposure to any particular source of risk

# %% [markdown]
# ### Chap8. Index Models
# 1. A single-factor model of the economy classifies sources of uncertainty as sysmatic(macro-economic) factor or firm-specific(microeconomic) factors.
# The index model assumes that the macro factor can be representred by a broad index of stock returns.
# 2. The single-index model drastically reduces the necessary inputs in the Markowitz portfolio selection procedure.
# it also aids in specialization of labor in security analysis.
# 3. According to the index model specification, the systematic risk of a portfolio or asset equals $β^2  σ_M^2$ and the covariance between two assets equals $β_i β_j σ_M^2$
# 4. The index  models is esimated by applying regression analysis to excess rates of return.
# The slope of the regression curve is the beta of an asset, whereas the intercept is the assest's alpha during the sample period. The resgression line is aloso called the security characterisitic line.
# 5. Practitioners routinely estimate the index model using total rather than excess rates of return.
# This makes their estimate of alpha equal to $\alpha$ + $\gamma$(1 - $\beta$).
# 6. Betas show a tendency to evolve toward 1 overtime. Beta forecasting ryles attempt to predict this drift.
# Moreover, other financial variavles can be to help forecast betas.
# 7. Optimal active portfolios include analyed securities in direct proportion to their alpha and in inverse prorportion to their firm-specific variance. The full risky portfolio is a mixture of the active active portfolio and the passive market-index portfolio. The index portfolio is used to enhance the diversification of the overall risky position.

# %% [markdown]
# ## Assignment. 2

# %% [markdown]
# ### Chap 7. Optimtimal Risky Portfolio
#
# Q1. The universe of available securities includes two risky stock funds, A and B, and T-bills. The data for the universe are as follows:
# Expected Return {A : 10%, B : 30, T-bills : 5} Standard Deviation{A : 20%, B : 60, T-bills : 0}.
# The correlation coefficient between funds A and B is −.2.
# a. Compute the opportunity set of funds A and B.
# b. Find the optimal risky portfolio, P, and its expected return and standard deviation.
# c. Find the slope of the CAL supported by T-bills and portfolio P.
# d. How much will an investor with A = 5 invest in funds A and B and in T-bills?
#
# Answers
# a. The covariance between the funds is
# $$Cov(r_A, r_B) = ρ(A, B) × σ_A × σ_B = −.2 × 20 × 60 = −240$$
#
# b. The proportions in the optimal risky portfolio are given by
# $$w_A = \frac{(10 − 5)60^2 − (30 − 5)(−240)}{(10 − 5)60^2 + (30 − 5)20^2 − 30(−240)} = .6818$$
# $$w_B = 1 − wA = .3182$$
# The expected return and standard deviation of the optimal risky portfolio are $$E(r_P) = (.6818 × 10) + (.3182 × 30) = 16.36%$$
# $$σ_P = {(.68182 × 202) + (.31822 × 602) +  [2 × .6818 × .3182( − 240)]}^{1/2}$$
# $$= 21.13%$$
# Note that portfolio P is not the global minimum-variance portfolio. The proportions of the latter are given by 602 − (−240) wA = __________________ 602 + 202 − 2(−240)    = .8571 wB = 1 − wA = .1429 With these proportions, the standard deviation of the minimum-variance portfolio is σ(min) = (.85712 × 202) + (.14292 × 602) + [2 × .8571 × .1429 × (−240)]1/2 = 17.75% which is less than that of the optimal risky portfolio.
#
# c. The CAL is the line from the risk-free rate through the optimal risky portfolio. This line represents all efficient portfolios that combine T-bills with the optimal risky portfolio.  The slope of the CAL is  $$S = \frac{E(r_P) − rf}{σ_P} = \frac{16.36 − 5}{21.13} = .5376$$
# d. Given a degree of risk aversion, A, an investor will choose the following proportion, y, in the optimal risky portfolio (remember to express returns as decimals when using A):
# $$y = \frac{E(r_P) − rf}{Aσ_P^2} = \frac{.1636 − .05}{5 × .21132} = .5089$$
#  This means that the optimal risky portfolio, with the given data, is attractive enough for an investor with A = 5 to invest 50.89% of his or her wealth in it. Because stock A makes up 68.18% of the risky portfolio and stock B makes up 31.82%, the investment proportions for this investor are
#  $$Stock A: .5089 × 68.18 = 34.70%$$
#  $$Stock B: .5089 × 31.82 = 16.19%$$
#  $$Total : 50.89%$$
#
# Q2. Suppose that the universe of available risky securities consists of a large number of stocks, identically distributed with E(r) = 15%, σ = 60%, and a common correlation coefficient of ρ = .5.
#
# a.What are the expected return and standard deviation of an equally weighted risky portfolio of 25 stocks?
# b.What is the smallest number of stocks necessary to generate an efficient portfolio with a standard deviation equal to or smaller than 43%?
# c. What is the systematic risk in this security universe?
# d.If T-bills are available and yield 10%, what is the slope of the CML? (Because of the symmetry assumed for all securities in the investment universe, the market index in this economy will be an equally weighted portfolio of all stocks.)
#
# Answers
# The parameters are E(r) = 15, σ = 60, and the correlation between any pair of stocks is ρ = .5.
# a. The portfolio expected return is invariant to the size of the portfolio because all stocks have identical expected returns. The standard deviation of a portfolio with n = 25 stocks is
#
# $$σ_P = [σ_2 / n + ρ × σ^2(n − 1) / n]^{1/2}$$
# $$ = [60^2 / 25 + .5 × 60^2 × 24 / 25]^{1/2} = 43.27\% $$
# b. Because the stocks are identical, efficient portfolios are equally weighted. To obtain a standard deviation of 43%, we need to solve for n:
#
# $$ 43^2 = \frac{60^2}{n} + .5 × \frac{60^2(n − 1)}{n}$$
# $$1,849n = 3,600 + 1,800n − 1,800$$
# $$n = \frac{1,800}{49} = 36.73$$
# Thus we need 37 stocks and will come in with volatility slightly under the target.
# c. As n gets very large, the variance of an efficient (equally weighted) portfolio diminishes, leaving only the variance that comes from the covariances among stocks. Therefore,
#
# $$Systematic \space standard \space deviation = \sqrt{ρ × σ^2} = \sqrt{.5 × 60^2} = 42.43%$$
# Note that with 25 stocks we came within .84% of the systematic risk, that is, the standard deviation of a portfolio of 25 stocks is only .84% higher than 42.43%. With 37 stocks, the standard deviation is 43.01%, which is only .58% greater than 42.43%.
#
# d. If the risk-free is 10%, then the risk premium on any size portfolio is 15 − 10 = 5%. The standard deviation of a well-diversified portfolio is (practically) 42.43%;
# hence the slope of the CAL is
# $$S = 5 / 42.43 = .1178$$

# %% [markdown]
# ### Chap8. Index Models
# Q1. The data below describe a three-stock financial market that satisfies the single-index model. Stock (A B C), Capitaliztion ($3,000  1,940  1,360), Beta (1.0 0.2 1.7), Mean Excess Return (10% 2 17), Standard Deviation (40% 30 50), The standard deviation of the market-index portfolio is 25%.
#
# a.What is the mean excess return of the index portfolio?
# b.What is the covariance between stock A and stock B?
# c. What is the covariance between stock B and the index?
# d.Break down the variance of stock B into its systematic and firm-specific components.
#
#
# Answers
# a. Total market capitalization is 3,000 + 1,940 + 1,360 = 6,300. Therefore, the mean excess return of the index portfolio is
# $$\frac{3,000}{6,300} × 10 + \frac{1,940}{6,300} × 2 + \frac{1,360}{6,300}   × 17 = 9.05% = .0905 $$
# b.The covariance between stocks A and B equals
# $$Cov(R_A,  R_B)= β_A β_B σ_M^2  = 1 × .2 ×  .25  2  = .0125$$
# c. The covariance between stock B and the index portfolio equals
#  $$Cov(R_B,  R_M) = β_B σ_M^2 = .2 × .25^2 = .0125$$
# d. The total variance of B equals
# $$σ_B^2 = Var(β_B R_M+  eB) = β_B^2σ_M^2   +  σ^2(e_B)$$
# Systematic risk equals $β_B^2σ_M^2 = .22 × .252 = .0025.$
# Thus the firm-specific variance of B equals
# $$σ^2(eB) = σ_B^2 − β_B^2σ_M^2 = .302 − .22 × .252 = .0875$$
#
#
# Q2. Table 8.2 shows that the estimate of Microsoft’s index-model α (per month) regression was .8%. If the monthly T-bill rate during this period was .2%, then what would you predict would be the value of ALPHA reported in a standard industry beta book?(For Miscrosoft β = .856)
#
# Answers
# The industry “beta-book” ALPHA is related to the index-model α by
# $$ALPHA=  α_{index model} + (1 − β)r_f$$
# For Microsoft, α = 0.8%, β = .856, and we are told that $r_f$ was .2% per month. Thus ALPHA =  0.8 + (1 − .856) × 0.2% = .8288.
# The index model and beta-book alpha are quite close in this case because rf is small and because β is close to 1.

# %% [markdown]
# ## Assignment. 3

# %% [markdown]
# ### Problem.1

# %% [markdown]
# # Lab Session Notebook - Returns
#
# ## From Prices to Returns
#
# Computing returns, and compounding a sequence of returns

# %%
prices_a = [8.70, 8.91, 8.71]

# %% [markdown]
# The return from time $t$ to time ${t+1} is given by:
#
# $$ R_{t,t+1} = \frac{P_{t+1}-P_{t}}{P_{t}} $$
#
# or alternately
#
# $$ R_{t,t+1} = \frac{P_{t+1}}{P_{t}} - 1 $$

# %%
import numpy as np
prices_a = np.array([8.70, 8.91, 8.71])
prices_a[1:]/prices_a[:-1] - 1
# Out:
# array([ 0.02413793, -0.02244669])

# %%
import pandas as pd
prices = pd.DataFrame({"BLUE": [8.70, 8.91, 8.71, 8.43, 8.73],
                       "ORANGE": [10.66, 11.08, 10.71, 11.59, 12.11]})
prices
# Out:
#    BLUE  ORANGE
# 0  8.70   10.66
# 1  8.91   11.08
# 2  8.71   10.71
# 3  8.43   11.59
# 4  8.73   12.11

# %% [markdown]
# However, because Pandas DataFrames will align the row index (in this case: 0, 1, 2, 3, 4) the exact same code fragment will not work as you might expect.

# %% [markdown]
# First, we can extract the values of the DataFrame column which returns a numpy array, so that the DataFrame does not try and align the rows.

# %%
prices.iloc[1:].values/prices.iloc[:-1] - 1
# Out:
#        BLUE    ORANGE
# 1  0.024138  0.039400
# 2 -0.022447 -0.033394
# 3 -0.032147  0.082166
# 4  0.035587  0.044866

# %%
prices.iloc[1:]/prices.iloc[:-1].values - 1
# Out:
#        BLUE    ORANGE
# 1  0.024138  0.039400
# 2 -0.022447 -0.033394
# 3 -0.032147  0.082166
# 4  0.035587  0.044866

# %% [markdown]
# these are probably a bit cleaner and more readable. The first option is to use the `.shift()` method on the array, which realigns the indices.

# %%
returns = prices/prices.shift(1) - 1
returns
# Out:
#        BLUE    ORANGE
# 0       NaN       NaN
# 1  0.024138  0.039400
# 2 -0.022447 -0.033394
# 3 -0.032147  0.082166
# 4  0.035587  0.044866

# %% [markdown]
# there is a built-in method in DataFrame that computes the percent change from one row to another. Since that is exactly what a return is (the percent change in price) we can just use this method to compute the return.

# %%
returns = prices.pct_change()
returns
# Out:
#        BLUE    ORANGE
# 0       NaN       NaN
# 1  0.024138  0.039400
# 2 -0.022447 -0.033394
# 3 -0.032147  0.082166
# 4  0.035587  0.044866

# %% [markdown]
# Pandas provides a convenient and simple way to read in a CSV file of the returns.

# %%
prices = pd.read_csv('/content/drive/MyDrive/csv/data/sample_prices.csv')
prices
# Out:
#       BLUE   ORANGE
# 0   8.7000  10.6600
# 1   8.9055  11.0828
# 2   8.7113  10.7100
# 3   8.4346  11.5907
# 4   8.7254  12.1070
# 5   9.0551  11.7876
# 6   8.9514  11.2078
# 7   9.2439  12.5192
# 8   9.1276  13.3624
# 9   9.3976  14.4080
# 10  9.4554  11.9837
# 11  9.5704  12.2718
# 12  9.7728  11.5892

# %%
returns = prices.pct_change()
returns
# Out:
#         BLUE    ORANGE
# 0        NaN       NaN
# 1   0.023621  0.039662
# 2  -0.021807 -0.033638
# 3  -0.031763  0.082232
# 4   0.034477  0.044544
# 5   0.037786 -0.026381
# 6  -0.011452 -0.049187
# 7   0.032676  0.117008
# 8  -0.012581  0.067353
# 9   0.029581  0.078249
# 10  0.006151 -0.168261
# 11  0.012162  0.024041
# 12  0.021149 -0.055623

# %%
returns.mean()
returns.std()
# Out:
# BLUE      0.023977
# ORANGE    0.079601
# dtype: float64

# %%
returns.plot.bar()

# %%
prices.plot()

# %% [markdown]
# ## Compounding Returns
#
# Now that we have a series of 12 monthly returns, we can produce the compounded return by multiplying the individual period returns, as long as the returns are expressed as growth rates in what I call "1+R" format.
#
# To compound the returns, all we need to do is add 1 to each return and then multiply them. The result is itself in "1+R" format, so we need to subtract 1.

# %%
returns + 1
# Out:
#         BLUE    ORANGE
# 0        NaN       NaN
# 1   1.023621  1.039662
# 2   0.978193  0.966362
# 3   0.968237  1.082232
# 4   1.034477  1.044544
# 5   1.037786  0.973619
# 6   0.988548  0.950813
# 7   1.032676  1.117008
# 8   0.987419  1.067353
# 9   1.029581  1.078249
# 10  1.006151  0.831739
# 11  1.012162  1.024041
# 12  1.021149  0.944377

# %%
(returns+1).prod()
(returns+1).prod()-1
(((returns+1).prod()-1)*100).round(2)
# Out:
# BLUE      12.33
# ORANGE     8.72
# dtype: float64

# %% [markdown]
# ## Annualizing Returns
#
# To annualize a return for a period, you compound the return for as many times as there are periods in a year. For instance, to annualize a monthly return you compund that return 12 times. The formula to annualize a monthly return $R_m$ is:
#
# $$ (1+R_m)^{12} - 1$$
#
# To annualize a quarterly return $R_q$ you would get:
#
# $$ (1+R_q)^{4} - 1$$
#
# And finally, to annualize a daily return $R_d$ you would get:
#
# $$ (1+R_d)^{252} - 1$$
#
# For example, to annualize a 1% monthly, and 4% quarterly and a 0.01% daily return you would do:

# %%
rm = 0.01
(1+rm)**12 - 1
# Out:
# 0.12682503013196977

# %%
rq = 0.04
(1+rq)**4 - 1
# Out:
# 0.1698585600000002

# %% [markdown]
# ## Problem.2.a

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
TB3MS = pd.read_csv('/content/drive/MyDrive/csv/TB3MS.csv')
TB3MS['DATE'] = pd.to_datetime(TB3MS['DATE'])
TB3MS.set_index('DATE', inplace = True)
TB3MS
# Out:
#             TB3MS
# DATE
# 1934-01-01   0.72
# 1934-02-01   0.62
# 1934-03-01   0.24
# 1934-04-01   0.15
# 1934-05-01   0.16
# ...           ...
# 2022-09-01   3.13
# 2022-10-01   3.72
# 2022-11-01   4.15
# 2022-12-01   4.25
# 2023-01-01   4.54
#
# [1069 rows x 1 columns]

# %%
aapl, snp500 = yf.Ticker('AAPL'), yf.Ticker('^GSPC')

aapl_his = aapl.history(period = 'max', interval = '1mo')
snp500_his = snp500.history(period = 'max',interval = '1mo')

aapl_his['return_aapl'] = aapl_his['Close'].pct_change()*100
snp500_his['return_snp500'] = snp500_his['Close'].pct_change()*100

AAPL = aapl_his[['return_aapl']]
SNP500 = snp500_his[['return_snp500']]

AAPL.index = AAPL.index.strftime('%Y-%m-%d')
SNP500.index = SNP500.index.strftime('%Y-%m-%d')
AAPL.index = pd.to_datetime(AAPL.index)
SNP500.index = pd.to_datetime(SNP500.index)
AAPL.index.name = AAPL.index.name.upper()
SNP500.index.name = SNP500.index.name.upper()

# %%
AAPL
# Out:
#             return_aapl
# DATE
# 1985-01-01          NaN
# 1985-02-01   -14.655051
# 1985-03-01   -10.606286
# 1985-04-01    -3.954563
# 1985-05-01   -18.235219
# ...                 ...
# 2022-10-01    10.955142
# 2022-11-01    -3.462881
# 2022-12-01   -12.081655
# 2023-01-01    11.052102
# 2023-02-01     7.815630
#
# [458 rows x 1 columns]

# %%
SNP500
# Out:
#             return_snp500
# DATE
# 1985-01-01            NaN
# 1985-02-01       0.862878
# 1985-03-01      -0.287001
# 1985-04-01      -0.459428
# 1985-05-01       5.405105
# ...                   ...
# 2022-10-01       7.986341
# 2022-11-01       5.375289
# 2022-12-01      -5.897147
# 2023-01-01       6.175286
# 2023-02-01       1.741647
#
# [458 rows x 1 columns]

# %%
AAPL_TB = pd.merge(AAPL,TB3MS, left_index = True, right_index = True, how = 'left')
AAPL_TB['ra_rf'] = AAPL_TB['return_aapl'] - AAPL_TB['TB3MS']
SNP500_TB = pd.merge(SNP500,TB3MS, left_index = True, right_index = True, how = 'left')
SNP500_TB['rsnp_rf'] = SNP500_TB['return_snp500'] - SNP500_TB['TB3MS']

# %%
AAPL_TB.isna().sum()
# Out:
# return_aapl    1
# TB3MS          1
# ra_rf          2
# dtype: int64

# %%
SNP500_TB
# Out:
#             return_snp500  TB3MS    rsnp_rf
# DATE
# 1985-01-01            NaN   7.76        NaN
# 1985-02-01       0.862878   8.27  -7.407122
# 1985-03-01      -0.287001   8.52  -8.807001
# 1985-04-01      -0.459428   7.95  -8.409428
# 1985-05-01       5.405105   7.48  -2.074895
# ...                   ...    ...        ...
# 2022-10-01       7.986341   3.72   4.266341
# 2022-11-01       5.375289   4.15   1.225289
# 2022-12-01      -5.897147   4.25 -10.147147
# 2023-01-01       6.175286   4.54   1.635286
# 2023-02-01       1.741647    NaN        NaN
#
# [458 rows x 3 columns]

# %%
Excess_aapl = AAPL_TB.loc['2013-01-01':'2023-01-01'][['ra_rf']]
Excess_snp500 = SNP500_TB.loc['2013-01-01':'2023-01-01'][['rsnp_rf']]
data = pd.concat([Excess_aapl,Excess_snp500], axis = 1)
data.plot(kind='scatter',x = 'rsnp_rf',y = 'ra_rf')
plt.xlabel('S&P500')
plt.ylabel('Apple')
# Out:
# Text(0, 0.5, 'Apple')

# %% [markdown]
# ## Problem.2.b

# %%
data
# Out:
#                 ra_rf    rsnp_rf
# DATE
# 2013-01-01 -14.478936   4.972810
# 2013-02-01  -3.193359   1.006065
# 2013-03-01   0.779926   3.508772
# 2013-04-01  -0.032858   1.748577
# 2013-05-01   1.529582   2.036281
# ...               ...        ...
# 2022-09-01 -15.105604 -12.469567
# 2022-10-01   7.235153   4.266341
# 2022-11-01  -7.612901   1.225289
# 2022-12-01 -16.331646 -10.147147
# 2023-01-01   6.512102   1.635286
#
# [121 rows x 2 columns]

# %%
rsnp_rf = sm.add_constant(data['rsnp_rf'], has_constant = 'add')
ra_rf = data['ra_rf']
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model = sm.OLS(ra_rf, rsnp_rf)
fit_model = model.fit()
print(fit_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  ra_rf   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.429
# Method:                 Least Squares   F-statistic:                     91.23
# Date:                Thu, 16 Feb 2023   Prob (F-statistic):           2.16e-16
# Time:                        10:38:39   Log-Likelihood:                -392.48
# No. Observations:                 121   AIC:                             789.0
# Df Residuals:                     119   BIC:                             794.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.1472      0.569      2.017      0.046       0.021       2.273
# ...

# %% [markdown]
# α = 1.142
# β = 1.2242

# %% [markdown]
# ## Problem.2.c
# ### The p-value($r_{snp500}$) is less than the signigicance level($\alpha$ = 0.05)
# 1. Decision : Reject the null hypothesis.
# 2. Conclusion : 'There is insufficient evidence to conclude that there is a significant linear relationship between $r_{snp500}$ - $r_f$ and $r_{Apple}$ - $r_f$ because the correlation coefficient is significantly different from zero.

# %% [markdown]
# ## Problem.3.a

# %%
name = ['AAPL','MSFT','AMZN','GOOGL','NVDA']
df = yf.download(name)
df
# Out:
# [*********************100%***********************]  5 of 5 completed
#              Adj Close                                                 \
#                   AAPL        AMZN      GOOGL        MSFT        NVDA
# Date
# 1980-12-12    0.099722         NaN        NaN         NaN         NaN
# 1980-12-15    0.094519         NaN        NaN         NaN         NaN
# 1980-12-16    0.087582         NaN        NaN         NaN         NaN
# 1980-12-17    0.089749         NaN        NaN         NaN         NaN
# 1980-12-18    0.092351         NaN        NaN         NaN         NaN
# ...                ...         ...        ...         ...         ...
# 2023-02-09  150.639999   98.239998  95.010002  262.961365  223.369995
# 2023-02-10  151.009995   97.610001  94.570000  262.442657  212.649994
# 2023-02-13  153.850006   99.540001  94.610001  270.642120  217.880005
# 2023-02-14  153.199997   99.699997  94.680000  271.490021  229.710007
# ...

# %%
# df_return = df['Close'].pct_change(252)*100

# %% [markdown]
# ## Problem.3.b

# %%
returns = df['Close'].pct_change()
returns = returns.loc['2018-01-01':'2023-01-01']
returns
# Out:
#                 AAPL      AMZN     GOOGL      MSFT      NVDA
# Date
# 2018-01-02  0.017905  0.016708  0.018806  0.004793  0.030233
# 2018-01-03 -0.000174  0.012775  0.017061  0.004654  0.065814
# 2018-01-04  0.004645  0.004476  0.003884  0.008801  0.005271
# 2018-01-05  0.011385  0.016163  0.013260  0.012398  0.008474
# 2018-01-08 -0.003714  0.014425  0.003531  0.001020  0.030641
# ...              ...       ...       ...       ...       ...
# 2022-12-23 -0.002798  0.017425  0.016750  0.002267 -0.008671
# 2022-12-27 -0.013878 -0.025924 -0.020621 -0.007414 -0.071353
# 2022-12-28 -0.030685 -0.014692 -0.015677 -0.010255 -0.006019
# 2022-12-29  0.028324  0.028844  0.028249  0.027630  0.040396
# 2022-12-30  0.002469 -0.002138 -0.002487 -0.004938  0.000753
#
# [1259 rows x 5 columns]

# %%
annual_ret = returns.mean()*252
annual_ret
# Out:
# AAPL     0.280763
# AMZN     0.136567
# GOOGL    0.152596
# MSFT     0.254626
# NVDA     0.356781
# dtype: float64

# %%
annual_cov = returns.cov()*252
annual_cov
# Out:
#            AAPL      AMZN     GOOGL      MSFT      NVDA
# AAPL   0.112159  0.078175  0.073657  0.080285  0.115565
# AMZN   0.078175  0.128134  0.076749  0.079484  0.120099
# GOOGL  0.073657  0.076749  0.098562  0.078759  0.109588
# MSFT   0.080285  0.079484  0.078759  0.096376  0.115867
# NVDA   0.115565  0.120099  0.109588  0.115867  0.269218

# %% [markdown]
# ## Problem.3.c

# %%
import seaborn as sns

# %%
port_ret = []
port_risk = []
port_weights = []
sharpe = []
for _ in range(20000):
    weights = np.random.random(len(returns.columns))
    weights /= np.sum(weights)

    temp_returns = np.dot(weights,annual_ret)
    temp_risk = np.sqrt(np.dot(weights.T, np.dot(annual_cov, weights)))

    port_ret.append(temp_returns)
    port_risk.append(temp_risk)
    port_weights.append(weights)
    sharpe.append((temp_returns -0.02) / temp_risk)
portfolio = {'Returns' : port_ret, 'Risk': port_risk, 'Sharpe': sharpe}

# %%
portfolio = pd.DataFrame(portfolio)
portfolio
# Out:
#         Returns      Risk    Sharpe
# 0      0.212959  0.308574  0.625326
# 1      0.264769  0.321280  0.761857
# 2      0.251536  0.339852  0.681284
# 3      0.200091  0.319910  0.562944
# 4      0.241862  0.345888  0.641428
# ...         ...       ...       ...
# 19995  0.198718  0.300413  0.594908
# 19996  0.252501  0.330090  0.704358
# 19997  0.235772  0.344294  0.626707
# 19998  0.257091  0.336328  0.704938
# 19999  0.219606  0.322112  0.619679
#
# [20000 rows x 3 columns]

# %%
portfolio.plot.scatter(x ='Risk', y = 'Returns', c = 'Sharpe', cmap = 'viridis', edgecolors ='k', grid = True)

# %% [markdown]
# ## Problem.3.d

# %%
max_sharpe = portfolio.loc[portfolio['Sharpe'] == portfolio['Sharpe'].max()]
min_risk = portfolio.loc[portfolio['Risk'] == portfolio['Risk'].min()]

# %%
portfolio.plot.scatter(x ='Risk', y = 'Returns', c = 'Sharpe', cmap = 'viridis', edgecolors ='k', grid = True)
plt.scatter(x=min_risk['Risk'], y=min_risk['Returns'], c ='r', marker ='X',s=200)
plt.scatter(x=max_sharpe['Risk'], y=max_sharpe['Returns'], c ='r', marker ='*',s=300)
plt.title('Efficient Frontier')
plt.xlabel('Risk')
plt.ylabel('Expected Returns')
plt.show()
